# %% [markdown]
# ## K-means Clustering

# %%
import pandas as pd
df = pd.read_csv("StudentJob.csv",encoding = "big5")
df
# Out:
#      code         type  salary  working
# 0    1401       綜合教育學類   37423     0.84
# 1    1402     普通科目教育學類   34327     0.85
# 2    1403     專業科目教育學類   34619     0.85
# 3    1404       學前教育學類   32645     0.91
# 4    1405       成人教育學類   30753     0.86
# 5    1406       特殊教育學類   44859     0.93
# 6    1407       教育行政學類   31545     0.81
# 7    1408       教育科技學類   28474     0.89
# 8    1499       其他教育學類   37638     0.89
# 9    2101         美術學類   29377     0.76
# 10   2102       雕塑藝術學類   33485     0.54
# 11   2103       美術工藝學類   24842     0.87
# 12   2104         音樂學類   31875     0.66
# 13   2105       戲劇舞蹈學類   30066     0.77
# 14   2106       視覺藝術學類   29914     0.80
# 15   2107       綜合藝術學類   29871     0.78
# 16   2108       民俗藝術學類   28217     0.58
# 17   2109       應用藝術學類   30450     0.77
# 18   2110       藝術行政學類   27005     0.70
# 19   2201       台灣語文學類   28427     0.85
# 20   2202       中國語文學類   31029     0.83
# 21   2203       外國語文學類   30313     0.85
# 22   2204       其他語文學類   35684     0.89
# 23   2205         翻譯學類   30426     0.89
# 24   2207         語言學類   28770     0.85
# 25   2208         宗教學類   27366     0.74
# 26   2209         歷史學類   30347     0.76
# 27   2210        人類學學類   30988     0.86
# 28   2211         哲學學類   30394     0.79
# 29   2299       其他人文學類   33020     0.84
# ..    ...          ...     ...      ...
# 112  6210         林業學類   29608     0.77
# 113  6211         漁業學類   26897     0.85
# 114  6401         獸醫學類   32824     0.85
# 115  7201         醫學學類   95360     0.98
# 116  7202       公共衛生學類   30414     0.85
# 117  7203         藥學學類   47275     0.85
# 118  7204       復健醫學學類   38140     0.87
# 119  7205         營養學類   28415     0.85
# 120  7206         護理學類   49785     0.96
# 121  7207    醫學技術及檢驗學類   34624     0.84
# 122  7208         牙醫學類   58937     0.82
# 123  7299     其他醫藥衛生學類   50951     1.00
# 124  7602       老年服務學類   33161     0.90
# 125  7603       社會工作學類   33049     0.90
# 126  7604       兒童保育學類   25809     0.92
# 127  8101       餐旅服務學類   28222     0.88
# 128  8102       觀光休閒學類   28053     0.87
# 129  8103       競技運動學類   39999     0.85
# 130  8104       運動科技學類   27965     0.80
# 131  8105  運動休閒及休閒管理學類   28468     0.87
# 132  8106     生活應用科學學類   26738     0.89
# 133  8107         服飾學類   29504     0.83
# 134  8108         美容學類   28710     0.88
# 135  8199       其他民生學類   31530     0.92
# 136  8401       運輸管理學類   32975     0.88
# 137  8402         航空學類   30564     0.91
# 138  8403         航海學類   49321     0.89
# 139  8501       環境資源學類   27582     0.91
# 140  8502       環境防災學類   26988     0.89
# 141  8601         警政學類   25693     0.84
#
# [142 rows x 4 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')
from sklearn.cluster import KMeans

df.salary = df.salary.astype(float)                   #traform into float type
df.working = df.working.astype(float)                 #traform into float type
X = df[['salary','working']].values                   #tranform DataFrame to Matrix 

y_pred = KMeans(n_clusters=4).fit_predict(X)
plt.figure(figsize=(12, 9))
plt.xlabel('Salary')
plt.ylabel('Rate of working')
plt.scatter(X[:, 0], X[:, 1], c=y_pred)
plt.show()

# %%
df[df.salary > 90000]
# Out:
#      code  type   salary  working
# 115  7201  醫學學類  95360.0     0.98
